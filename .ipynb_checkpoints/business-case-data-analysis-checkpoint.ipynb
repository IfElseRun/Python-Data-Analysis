# %%
from connection import MySQLConnection
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


new_connection = MySQLConnection()
# Out:
# Connection successfull and records already exist.

# %%
# 
# SQL query o
q = ('''SELECT cast(year(INSPECTION_DATE) as nchar) AS `YEAR`,BORO AS BOROUGH, AVG(WEIGHED_SCORE) AS `AVERAGE SCORE`, COUNT(SCORE) AS `NUMBER OF INSPECTIONS`
FROM nyc_restaurants.clean_data
GROUP BY BOROUGH, `YEAR`''')

# Convert the SQL query to Pandas DataFrame
r = pd.read_sql(q,  new_connection.con)
df_pivot = pd.pivot_table(
    r,
    values="AVERAGE SCORE",
    index="YEAR",
    columns="BOROUGH",
    aggfunc=np.mean
)
# Plot a bar chart using the DF
ax = df_pivot.plot(kind="bar")
# Get a Matplotlib figure from the axes object for formatting purposes
fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(15,5)
# Change the axes labels
ax.set_xlabel("Years")
ax.set_ylabel("AVERAGE SCORE")

print(r)
r = r.pivot(index='YEAR', columns='BOROUGH', values='AVERAGE SCORE')
r = r.plot(grid=True)
fig = r.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(15,5)
plt.show()
# Out:
#     YEAR        BOROUGH  AVERAGE SCORE  NUMBER OF INSPECTIONS
# 0   2018          Bronx        87.1201                   2831
# 1   2019          Bronx        85.9421                   6170
# 2   2020          Bronx        88.2602                   1295
# 3   2021          Bronx        87.1995                    777
# 4   2022          Bronx        86.3802                   1423
# 5   2018       Brooklyn        86.9018                   5731
# 6   2019       Brooklyn        87.2072                  15306
# 7   2020       Brooklyn        87.6102                   3479
# 8   2021       Brooklyn        86.8575                   3157
# 9   2022       Brooklyn        85.9159                   4398
# 10  2018      Manhattan        86.9014                  10815
# 11  2019      Manhattan        87.1680                  23357
# 12  2020      Manhattan        87.5896                   5551
# 13  2021      Manhattan        87.8596                   3134
# ...

# %%
r = pd.read_sql(q,  new_connection.con)
m = r.groupby('YEAR')['AVERAGE SCORE'].transform('max') == r['AVERAGE SCORE']
print(r[m])
# Out:
#     YEAR        BOROUGH  AVERAGE SCORE  NUMBER OF INSPECTIONS
# 2   2020          Bronx        88.2602                   1295
# 20  2018  Staten Island        87.3273                    938
# 21  2019  Staten Island        88.0759                   1818
# 23  2021  Staten Island        89.1714                    426
# 24  2022  Staten Island        87.0656                    701

# %%
# 
# SQL query o
#q1 = ('''SELECT a.* FROM ( SELECT cast(year(INSPECTION_DATE) as nchar) AS `YEAR`, CUISINE_DESCRIPTION, cast(AVG(WEIGHED_SCORE) as int) AS `AVERAGE SCORE`, COUNT(SCORE) AS `NUMBER OF INSPECTIONS`, RANK() OVER ( PARTITION BY `YEAR` ORDER BY `AVERAGE SCORE` DESC ) score_rank FROM nyc_restaurants.clean_data WHERE BORO = 'Staten Island' GROUP BY `YEAR`, CUISINE_DESCRIPTION ) AS a WHERE a.score_rank <= 5 ORDER BY a.`YEAR` ASC, a.score_rank ASC;''')
"""
q1 = ('''select 
            `a`.*
            from (
                select 
                    cast(year(`clean_data`.`INSPECTION_DATE`) AS nchar) AS `YEAR`,
                    `clean_data`.`CUISINE_DESCRIPTION` AS `CUISINE_DESCRIPTION`,
                    avg(`clean_data`.`WEIGHED_SCORE`) AS `AVERAGE SCORE`,
                    count(`clean_data`.`SCORE`) AS `NUMBER OF INSPECTIONS`,
                    rank() over ( partition by year(`clean_data`.`INSPECTION_DATE`) order by avg(`clean_data`.`WEIGHED_SCORE`) desc) AS `score_rank`,
                    LAST_VALUE(year(`clean_data`.`INSPECTION_DATE`)) OVER (
                        PARTITION BY `clean_data`.`CUISINE_DESCRIPTION`
                        ORDER BY year(`clean_data`.`INSPECTION_DATE`)
                        RANGE BETWEEN
                            UNBOUNDED PRECEDING AND
                            UNBOUNDED FOLLOWING
                    ) `last_year`
                from `nyc_restaurants`.`clean_data` 
                where `clean_data`.`BORO` = 'Staten Island'
                group by year(`clean_data`.`INSPECTION_DATE`),`clean_data`.`CUISINE_DESCRIPTION`
            ) `a`
            where `a`.`score_rank` <= 10 AND `last_year` = year(now())
            order by `a`.`YEAR`,`a`.`score_rank`;''')
"""
q1 = ('''SELECT * FROM nyc_restaurants.borough_cuisine_analysis;''')

# Convert the SQL query to Pandas DataFrame
r1 = pd.read_sql(q1,  new_connection.con)

#ax= r1.plot( kind = "scatter",x= 'YEAR',
#                    y='CUISINE_DESCRIPTION',
#                    c='AVERAGE SCORE',
#                    colormap='viridis',s=400,sharex=False)

ax = r1.plot.scatter(x = 'YEAR', y = 'CUISINE_DESCRIPTION', grid=True, s = 400, c = 'AVERAGE SCORE', colormap='viridis', sharex=False);

fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(20,10)

# %%
r1
m = r1.groupby('YEAR')['AVERAGE SCORE'].transform('max') == r1['AVERAGE SCORE']
print(r1[m])
# Out:
#     YEAR CUISINE_DESCRIPTION  AVERAGE SCORE  NUMBER OF INSPECTIONS  \
# 0   2018           Soul Food        98.0000                      2
# 7   2019               Other        93.3333                      6
# 11  2020     Frozen Desserts        94.2857                      7
# 20  2021       Mediterranean        93.0000                      1
# 28  2022          Hamburgers        91.4000                     15
#
#     score_rank  last_year
# 0            1       2022
# 7            3       2022
# 11           1       2022
# 20           1       2022
# 28           1       2022

# %%
# 
# SQL query o
"""
q2 = ('''SELECT a.* 
            FROM ( 
                SELECT 
                    cast(year(INSPECTION_DATE) as nchar) AS `YEAR`, 
                    CUISINE_DESCRIPTION, 
                    AVG(WEIGHED_SCORE) AS `AVERAGE SCORE`, 
                    COUNT(SCORE) AS `NUMBER OF INSPECTIONS`, 
                    CAMIS, 
                    DBA, 
                    RANK() OVER ( PARTITION BY `YEAR` ORDER BY `AVERAGE SCORE` DESC ) score_rank,
                    LAST_VALUE(year(INSPECTION_DATE)) OVER (
                                    PARTITION BY CUISINE_DESCRIPTION
                                    ORDER BY year(INSPECTION_DATE)
                                    RANGE BETWEEN
                                        UNBOUNDED PRECEDING AND
                                        UNBOUNDED FOLLOWING
                                ) last_year
                FROM nyc_restaurants.clean_data 
                WHERE BORO = 'Staten Island' AND CUISINE_DESCRIPTION = 'Coffee/Tea' 
                GROUP BY `YEAR`, DBA 
            ) AS a 
            WHERE a.`score_rank` <= 10 AND `last_year` = year(now())
            ORDER BY a.`YEAR` ASC, a.score_rank ASC;''')
"""
q2 = ('''SELECT * FROM nyc_restaurants.borough_cuisine_restaurant_analysis;''')

# Convert the SQL query to Pandas DataFrame
r2 = pd.read_sql(q2,  new_connection.con)
#df_pivot = pd.pivot_table(
#    r2,
#    values="AVERAGE SCORE",
#    index="YEAR",
#    columns="DBA",
#    aggfunc=np.mean
#)

ax = r2.plot.scatter(x = 'YEAR', y = 'DBA', s = 400, grid=True, c = 'AVERAGE SCORE', colormap='viridis', sharex=False);

# Plot a bar chart using the DF
#ax = df_pivot.plot(kind="bar")
# Get a Matplotlib figure from the axes object for formatting purposes
fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(20,10)
# Change the axes labels
ax.set_xlabel("Years")
ax.set_ylabel("AVERAGE SCORE")
# Out:
#   File "/tmp/ipykernel_303997/240484106.py", line 40
#     ax = r2.plot.scatter(x = 'YEAR', y = 'DBA', s = 400, grid=True c = 'AVERAGE SCORE', colormap='viridis', sharex=False);
#                                                                    ^
# SyntaxError: invalid syntax

# %%
r2
m = r2.groupby('YEAR')['AVERAGE SCORE'].transform('max') == r2['AVERAGE SCORE']
print(r2[m])
# Out:
#     YEAR                            DBA     CAMIS  AVERAGE SCORE  \
# 0   2018  FOOD FOR THOUGHT LIBRARY CAFE  40516511           95.0
# 4   2019             MAIN STREET COFFEE  50078660           98.0
# 15  2020         LIL M BUBBLE TEA HOUSE  50096442           98.0
# 16  2020               STARBUCKS COFFEE  50056784           98.0
# 18  2021                   MUSTARD SEED  50110595           97.0
# 24  2022       STARBUCKS COFFEE COMPANY  50108286           96.0
#
#     NUMBER OF INSPECTIONS  score_rank CUISINE_DESCRIPTION  last_year
# 0                       3           1          Coffee/Tea       2022
# 4                       1           1          Coffee/Tea       2022
# 15                      1           1          Coffee/Tea       2022
# 16                      1           1          Coffee/Tea       2022
# 18                      2           1          Coffee/Tea       2022
# 24                      1           1          Coffee/Tea       2022
